# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('..\\input\\jpx-tokyo-stock-exchange-prediction\\training_price_features.csv')
df.tail(5)
# Out:
#                  RowId        Date  SecuritiesCode    Open    High     Low  \
# 1880526  20201224_9997  2020-12-24            9997   995.0  1037.0   995.0
# 1880527  20201225_9997  2020-12-25            9997  1018.0  1072.0  1018.0
# 1880528  20201228_9997  2020-12-28            9997  1080.0  1096.0  1050.0
# 1880529  20201229_9997  2020-12-29            9997  1070.0  1095.0  1061.0
# 1880530  20201230_9997  2020-12-30            9997  1092.0  1140.0  1076.0
#
#           Close  Volume  AdjustmentFactor  ExpectedDividend  ...  \
# 1880526  1025.0  332300               1.0                 0  ...
# 1880527  1065.0  426200               1.0                 0  ...
# 1880528  1072.0  391400               1.0                 0  ...
# 1880529  1092.0  199000               1.0                 0  ...
# 1880530  1134.0  338900               1.0                 0  ...
#
#          ExpMovingAvg_20Day  Volatility_20Day  Return_30Day  MovingAvg_30Day  \
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['data_in_range'] = df['Date'].between('2020-12-01', '2020-12-31')
df_new = df.groupby('SecuritiesCode')['data_in_range'].sum().reset_index(name='counts')
df_new.describe()
# Out:
#        SecuritiesCode       counts
# count     2000.000000  2000.000000
# mean      5883.054000    21.941000
# std       2390.405164     0.886517
# min       1301.000000     6.000000
# 25%       3915.750000    22.000000
# 50%       6200.500000    22.000000
# 75%       7938.250000    22.000000
# max       9997.000000    22.000000

# %%
print(df_new[df_new['counts'] ==22]['SecuritiesCode'].values)
# Out:
# [1301 1332 1333 ... 9993 9994 9997]
