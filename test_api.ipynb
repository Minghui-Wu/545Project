# %%
from helper_files.local_api import local_api

# %%
myapi = local_api('input/jpx-tokyo-stock-exchange-prediction/train_files')
env = myapi.make_env()
# Out:
# d:\repo\545Project\helper_files\local_api.py:89: DtypeWarning: Columns (7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.options = pd.read_csv(os.path.join(data_dir, 'options.csv'))
# d:\repo\545Project\helper_files\local_api.py:90: DtypeWarning: Columns (14,15,16,17,18,19,42,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.financials = pd.read_csv(os.path.join(data_dir, 'financials.csv'))

# %%
iter_test = env.iter_test()
for (prices, options, financials, trades, secondary_prices, sample_prediction) in iter_test:
    env.predict(sample_prediction)
print(env.score())
sample_prediction.head()
# Out:
# 0.01992377818541857
#          Date  SecuritiesCode  Rank
# 0  2021-12-03            1301     0
# 1  2021-12-03            1332     1
# 2  2021-12-03            1333     2
# 3  2021-12-03            1375     3
# 4  2021-12-03            1376     4
